# %%
import pandas as pd

# %%
df = pd.read_excel("./base/Base 5.1.xlsx", sheet_name=None)
print("Sheets da planilha Base 5.1.xlsx")
print(df.keys())
# Out:
# Sheets da planilha Base 5.1.xlsx
# dict_keys(['Sheet1', 'PDFs_validos', 'Bloqueado_sem_Resumo', 'Bloqueado_com_Resumo', 'Sites'])
